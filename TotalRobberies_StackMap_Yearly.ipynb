# %%
#libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
Bank = [17,25,33,24,0]
Highway = [51,58,62,49,0]
Murder = [106,86,100,105,0]

# The position of the bars on the x-axis
r = [0,3,6,9,30]

# Names of group and bar width
names = ['2011','2012','2013','2014','']
barWidth = 0.8
 
# Create brown bars
plt.bar(r, Bank, label='Bank Robberies',color='skyblue', edgecolor='white', width=barWidth)
# Create green bars (middle), on top of the firs ones
plt.bar(r, Highway, bottom=Bank, label='Highway Robberies', color='orange', edgecolor='white', width=barWidth)
# Create green bars (top)
plt.bar(r, Murder, bottom=Highway,label='Murders during Robberies', color='gray', edgecolor='white', width=barWidth)
 
# Custom X axis
plt.xticks(r, names, fontweight='bold')
plt.xlabel("Total Robberies in Karachi")
plt.ylabel("Total Number of Robberies")
plt.legend(loc= "upper right", fancybox=True, framealpha=1, shadow=True, borderpad=1)
plt.title("Stack Map of Karachi Robberies 2011-2014")
# Show graphic
plt.show()
