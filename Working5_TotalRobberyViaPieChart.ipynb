# %%
import matplotlib.pyplot as plt
slices_hours = [99, 220,397]
activities = ['Bank Robbery', 'Highway Robbery', 'Murders']
colors = ['gray', 'orange', 'lightblue']
plt.pie(slices_hours, labels=activities, colors=colors, startangle=90, autopct='%.1f%%')
plt.title("Total Robberies in KHI 2011-2014")
plt.show()
